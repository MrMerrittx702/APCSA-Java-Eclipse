# %% [markdown]
# # **USEFUL METHODS**

# %% [markdown]
# ## Collections (Arrays/ArrayLists)

# %% [markdown]
# **Arrays**
#
# import java.util.Arrays;
#
# Static
# * binarySearch()
# * sort()
# * swap()
# * fill()
# * copyOf()
# * copyOfRange()
# * compare()
# * mismatch()
#
# Non Static
# * toString() to print out the value without looping
# * equals()
# * toArray()
# * contains()
# * replaceAll()

# %% [markdown]
# **ArrayLists**
#
# import java.util.ArrayLists;
#
# Non Static
# * toString() to print out the value without looping
# * equals()
# * sort()
# * toArray()
# * contains()
# * indexOf()
# * lastIndexOf()
# * replaceAll()
# * remove()
# * set()
# * get()
# * size()
# * add()
# * subList()

# %% [markdown]
# ## Math Class
# Class Attributes
# * Math.E
# * Math.PI
# * Math.DEGREES_TO_RADIANS
# * Math.RADIANS_TO_DEGREES
#
# Static Methods
# * sin()
# * cos()
# * tan()
# * asin()
# * acos()
# * atan()
# * toRadians()
# * toDegrees()
# * exp()
# * log()
# * log10()
# * sqrt()
# * cbrt()
# * ceil()
# * floor()
# * rint()
# * atan2()
# * pow()
# * round()
# * random()
# * floorDiv()
# * floorMod()
# * abs()
# * max()
# * min()
# * sinh()
# * cosh()
# * tanh()
# * powerOfTwoD()
# * powerOfTwoF()

# %% [markdown]
# ## Random Class
#
# Constructor
# * Random()
#
# Non Static
# * nextBytes()
# * nextInt()
# * nextLong()
# * nextBoolean()
# * nextFloat()
# * nextDouble()

# %% [markdown]
# ## Scanner Class
# Constructor
# * Scanner()
#
#
# Non Static
# * close()
# * toString()
# * hasNextLine()
# * nextLine()
# * findInLine()
# * skip()
# * hasNextBoolean()
# * nextBoolean()
# * hasNextByte()
# * nextByte()
# * hasNextShort()
# * nextShort()
# * hasNextInt()
# * nextInt()
# * hasNextLong()
# * nextLong()
# * hasNextFloat()
# * nextFloat()
# * hasNextDouble()
# * nextDouble()

# %% [markdown]
# ## String Class
#
# Constructor
# String()
# Static
# * valueOf()
# * copyValueOf()
# * join()
# * format()
#
# Non Static
# * length()
# * isEmpty()
# * charAt()
# * getChars()
# * getBytes()
# * equals()
# * equalsIgnoreCase()
# * compareTo()
# * regionMatches()
# * startsWith()
# * indexOf()
# * lastIndexOf()
# * substring()
# * concat()
# * replace()
# * matches()
# * contains()
# * replaceFirst()
# * replaceAll()
# * split()
# * toLowerCase()
# * toUpperCase()
# * trim()
# * strip()
# * stripLeading()
# * stripTrailing()
# * isBlank()
# * stripIndent()
# * translateEscapes()
# * formatted()
# * repeat()
